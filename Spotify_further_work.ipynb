# %%
# %run Spotify_cleaningV3.ipynb
import re
import numpy as np
import math
# %matplotlib inline
import warnings
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats
from sklearn import preprocessing


# Libraries to work with the data object
import pandas as pd 
import numpy as np
# libraries to visualize
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap


# sklearn as one of the most used machine learning package
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1255 entries, 0 to 1254
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      1255 non-null   object
#  1   artist     1255 non-null   object
#  2   top genre  1250 non-null   object
#  3   year       1255 non-null   int64
#  4   bpm        1255 non-null   int64
#  5   nrgy       1255 non-null   int64
#  6   dnce       1255 non-null   int64
#  7   dB         1255 non-null   int64
#  8   live       1255 non-null   int64
#  9   val        1255 non-null   int64
#  10  dur        1255 non-null   int64
#  11  acous      1255 non-null   int64
#  12  spch       1255 non-null   int64
#  13  pop        1255 non-null   int64
# dtypes: int64(11), object(3)
# memory usage: 137.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1250 entries, 0 to 1254
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ...

# %% [markdown]
# We want to look at the distribution with histogram for BPM, NRGY ect. to see the difference in years.
# We can do it for top genre, year.

# %%
data_new['pop'].describe()
# Out:
# count    1250.000000
# mean       68.740000
# std        10.304122
# min         7.000000
# 25%        63.000000
# 50%        70.000000
# 75%        76.000000
# max        95.000000
# Name: pop, dtype: float64

# %%
data_new['val'].describe()
# Out:
# count    1250.000000
# mean       52.093600
# std        21.625535
# min         4.000000
# 25%        36.000000
# 50%        52.000000
# 75%        69.000000
# max        97.000000
# Name: val, dtype: float64

# %%
data_new['nrgy'].describe()
# Out:
# count    1250.000000
# mean       68.985600
# std        15.768992
# min         6.000000
# 25%        59.000000
# 50%        71.000000
# 75%        81.000000
# max        98.000000
# Name: nrgy, dtype: float64

# %%
data_new['dB'].describe()
# Out:
# count    1250.000000
# mean       -5.597600
# std         1.930455
# min       -18.000000
# 25%        -7.000000
# 50%        -5.000000
# 75%        -4.000000
# max        -1.000000
# Name: dB, dtype: float64

# %%
sns.set(color_codes=True)
sns.distplot(data_new['spch'])  #replace europe with any other continent and see what happens
plt.show()

# %%
sns.catplot(x="top genre", y="pop", kind="box", height=7, aspect=1.5, data=data_new)

# %%
#popu = data_new.loc[data_new['top genre'] == 'pop'] 
rock = data_new.loc[data_new['top genre'] == 'rock']
electronic = data_new.loc[data_new['top genre'] == 'electronic'] 
rogb = data_new.loc[data_new['top genre'] == 'r&b']
pop = data_new.loc[data_new['top genre'] == 'pop']
rap = data_new.loc[data_new['top genre'] == 'rap']




fig = plt.figure(figsize=(10,6))
sns.set(color_codes=True)
sns.distplot(rock['pop'], color = 'pink', rug=True, hist=False)
sns.distplot(electronic['pop'], color = 'blue', rug=True, hist=False)
sns.distplot(rogb['pop'], color = 'red', rug=True, hist=False)
sns.distplot(pop['pop'], color ='yellow',rug=True, hist=False)
sns.distplot(rap['pop'], color = 'pink', rug=True, hist=False)


fig.legend(labels=['rock','electronic','rogb','pop','rap'])
plt.show()
#matplotlib does a better job at plotting than seaborn

# %%
#assign the selection of each continent in a new dataframe for ease of use, based on genre




#year_2011 = data_new.loc[dataset['year'] == 'Oceania']
#year_2015 = data_new.loc[dataset['year'] == 'Europe'] 
#year_2018 = data_new.loc[dataset['year'] == 'Africa']


#distribution plot with histogram



sns.set(color_codes=True)
sns.distplot(data_new['dB'])  #replace europe with any other continent and see what happens
plt.show()

# %%
sns.set(color_codes=True)
sns.distplot(data_new['val'])  #replace europe with any other continent and see what happens
plt.show()

# %%
sns.set(color_codes=True)
sns.distplot(data_new['nrgy'])  #replace europe with any other continent and see what happens
plt.show()

# %%
sns.set(color_codes=True)
sns.distplot(data_new['dB'])  #replace europe with any other continent and see what happens
plt.show()

# %%
sns.pairplot(data=data_new, hue="top genre")
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
rock = data_new.loc[data_new['top genre'] == 'rock'] 
pop = data_new.loc[data_new['top genre'] == 'pop']
hiphop = data_new.loc[data_new['top genre'] == 'hip hop']
rap = data_new.loc[data_new['top genre'] == 'rap']
soul = data_new.loc[data_new['top genre'] == 'soul']
r_b = data_new.loc[data_new['top genre'] == 'r&b']
electronic = data_new.loc[data_new['top genre'] == 'electronic']
country = data_new.loc[data_new['top genre'] == 'country']
indie = data_new.loc[data_new['top genre'] == 'indie']
latin = data_new.loc[data_new['top genre'] == 'latin']
metal = data_new.loc[data_new['top genre'] == 'metal']
reggae = data_new.loc[data_new['top genre'] == 'reggae']
kids = data_new.loc[data_new['top genre'] == 'kids']


sns.set(color_codes=True)
sns.distplot(pop['bpm'])  
plt.show()

sns.set(color_codes=True)
sns.distplot(hiphop['bpm'])  
plt.show()

sns.set(color_codes=True)
sns.distplot(rap['bpm'])  
plt.show()

sns.set(color_codes=True)
sns.distplot(soul['bpm'])  
plt.show()

sns.set(color_codes=True)
sns.distplot(r_b['bpm'])  
plt.show()

sns.set(color_codes=True)
sns.distplot(electronic['bpm'])  
plt.show()

sns.set(color_codes=True)
sns.distplot(country['bpm'])  
plt.show()

sns.set(color_codes=True)
sns.distplot(indie['bpm'])  
plt.show()

sns.set(color_codes=True)
sns.distplot(latin['bpm'])  
plt.show()

sns.set(color_codes=True)
sns.distplot(metal['bpm'])  
plt.show()

sns.set(color_codes=True)
sns.distplot(reggae['bpm'])  
plt.show()

sns.set(color_codes=True, labels=['kids'])
sns.distplot(kids['bpm'])  
plt.show()


#https://seaborn.pydata.org/generated/seaborn.distplot.html
#https://matplotlib.org/api/pyplot_api.html
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-1a66ccc86ff5> in <module>
#      58 plt.show()
#      59
# ---> 60 sns.set(color_codes=True, labels=['kids'])
#      61 sns.distplot(kids['bpm'])
#      62 plt.show()
#
# TypeError: set() got an unexpected keyword argument 'labels'

# %%
unique = data_new['top genre'].unique()
unique
# Out:
# array(['hip hop', 'metal', 'rock', 'rap', 'country', 'pop', 'latin',
#        'electronic', 'indie', 'r&b', 'soul', 'reggae', 'kids'],
#       dtype=object)

# %%
fig = plt.figure(figsize=(10,6))
sns.set(color_codes=True)
sns.distplot(pop['bpm'], color = 'blue', rug=True, hist=False)
sns.distplot(rock['bpm'], color ='yellow', rug=True, hist=False)
sns.distplot(hiphop['bpm'], color = 'red', rug=True, hist=False)
sns.distplot(rap['bpm'], color = 'purple', rug=True, hist=False)
sns.distplot(indie['bpm'], color = 'grey', rug=True, hist=False)
sns.distplot(electronic['bpm'], color = 'black', rug=True, hist=False)
sns.distplot(r_b['bpm'], color = 'white', rug=True, hist=False)
sns.distplot(country['bpm'], color = 'pink', rug=True, hist=False)
sns.distplot(reggae['bpm'], color = 'green', rug=True, hist=False)
sns.distplot(kids['bpm'], color = 'brown', rug=True, hist=False)
sns.distplot(metal['bpm'], color = 'magenta', rug=True, hist=False)
sns.distplot(soul['bpm'], color = 'hotpink', rug=True, hist=False)
sns.distplot(latin['bpm'], color = 'orange', rug=True, hist=False)


fig.legend(labels=['pop','rock', 'hiphop', 'rap', 'electronic', 'r&b', 'reggae', 'kids', 'country', 'latin', 'soul', 'metal'])
plt.show()
#matplotlib does a better job at plotting than seaborn

# %% [markdown]
# The first eye catcher is country with a BPM with big variation.
# Lowest BPM is kids music.
# It is possible to do same for others features, for an example year and nrgy.

# %% [markdown]
# ### we are trying with boxplots and catplots:

# %%
sns.catplot(x="top genre", y="pop", kind="box", height=7, aspect=1.5, data=data_new)

# %%
sns.catplot(x="top genre", y="year", kind="box", height=7, aspect=1.5, data=data_new)

# %%
data_new.columns
# Out:
# Index(['title', 'artist', 'top genre', 'year', 'bpm', 'nrgy', 'dnce', 'dB',
#        'live', 'val', 'acous', 'spch', 'pop', 'duration_sec', 'duration_min'],
#       dtype='object')

# %%
sns.catplot(x="dB", y="pop", kind="box", height=10, aspect=2.0, data=data_new)

# %%
plt.figure(figsize=(12,8)) # the size of the figure needs to be specifed before plotting
plt.scatter(x = data_new['dB'], y = data_new['pop'], alpha = 0.6)
# alpha parameter controls the opacity and transparency of the bubbles 
#plt.xscale('log') # what does this do? 

# the next functions add labels and title to the plot 
plt.xlabel('Loudness')
plt.ylabel('popularity')
plt.title('How loud the song is vs popularity score')

# Show the plot
plt.show()

# %%
data_new.head(20)
# Out:
#                             title           artist top genre  year  bpm  nrgy  \
# 0                A Bay Bay - MAIN  Hurricane Chris   hip hop  2007   77    70
# 1                  Better Than Me           Hinder     metal  2019  140    68
# 2                     Get Like Me     David Banner   hip hop  2008  118    74
# 3               How Do You Sleep?  Jesse McCartney   hip hop  2008  106    85
# 4                Lips Of An Angel           Hinder     metal  2019  129    74
# 6                          2 Step              Unk   hip hop  2012  154    78
# 7           Love Remains the Same   Gavin Rossdale      rock  2008  149    65
# 8      Who Says You Can't Go Home         Bon Jovi     metal  2010  132    94
# 9                         Leavin'  Jesse McCartney   hip hop  2008   79    72
# 10                        I Tried             Akon   hip hop  2013   82    83
# 11                    Cheerleader              OMI   hip hop  2014  100    74
# ...

# %% [markdown]
# I am coding a heatmap to see associations between features

# %%
sns.heatmap(data_new.corr(),cmap="YlOrRd")

# %%
plt.figure(figsize=(12,6))
g =sns.scatterplot(x="val", y="pop", hue="top genre", size = "pop", data=data_new)
g.set(xscale="log")

plt.show()

# %% [markdown]
# For our first trick we'll create a scatterplot based on the songs' valence and danceability values. In addition, we will also use linear regression to find their correlation.

# %%
x = data_new["pop"].values
y = data_new["dB"].values

x = x.reshape(x.shape[0], 1)
y = y.reshape(y.shape[0], 1)

regr = linear_model.LinearRegression()
regr.fit(x, y)

fig = plt.figure(figsize=(6, 6))
fig.suptitle("Correlation between the acousness and the popularity of the song")

ax = plt.subplot(1, 1, 1)
ax.scatter(x, y, alpha=0.5)
ax.plot(x, regr.predict(x), color="red", linewidth=3)

plt.xlabel("Acousness")
plt.ylabel("Popularity")

plt.show()

# %%
x = "dB"
y = "pop"

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=False, sharex=False, figsize=(10, 5))
fig.suptitle("Loudness (dB) and popularity " + "\n" + "histogram (left) and heatmap (right)")
h = ax2.hist2d(data_new[x], data_new[y], bins=20)
ax1.hist(data_new["pop"])

ax2.set_xlabel(x)
ax2.set_ylabel(y)

ax1.set_xlabel("dB")

plt.colorbar(h[3], ax=ax2)

plt.show()

# %% [markdown]
# Now to create some histograms. The plot on the left illustrates the distribution of songs based on their energy levels, whereas the one on the right is a "heatmap" (histogram in two dimensions) that illustrates the number of songs found at all values of valence and danceability.

# %% [markdown]
# Next, we generate a list of "chosen" traits and use principal component analysis to reduce the dimensions of that list to 3, effectively creating a matrix suitable for generating the following 3-dimensional plot. The lesser the distance between any two songs, the larger the similarities in their traits.

# %%
data_new.head()
# Out:
#                title           artist top genre  year  bpm  nrgy  dnce  dB  \
# 0   A Bay Bay - MAIN  Hurricane Chris   hip hop  2007   77    70    84  -5
# 1     Better Than Me           Hinder     metal  2019  140    68    45  -5
# 2        Get Like Me     David Banner   hip hop  2008  118    74    94  -4
# 3  How Do You Sleep?  Jesse McCartney   hip hop  2008  106    85    74  -4
# 4   Lips Of An Angel           Hinder     metal  2019  129    74    47  -5
#
#    live  val  acous  spch  pop  duration_sec  duration_min
# 0    10   74     11    39    7           307      5.116667
# 1    18   25     21     3   22           224      3.733333
# 2    25   70      0    38   24           226      3.766667
# 3    12   69     33     3   25           222      3.700000
# 4    32   23      3     4   28           252      4.200000

# %% [markdown]
# OBS! Læg mærke til, at dB har en negativ værdi. Hvorfor?

# %%
data_new.corr()
# Out:
#                   year       bpm      nrgy      dnce        dB      live  \
# year          1.000000  0.019705 -0.215871  0.143875 -0.128274 -0.101074
# bpm           0.019705  1.000000  0.115912 -0.177673  0.101843  0.060197
# nrgy         -0.215871  0.115912  1.000000 -0.165525  0.721893  0.169188
# dnce          0.143875 -0.177673 -0.165525  1.000000 -0.124034 -0.085405
# dB           -0.128274  0.101843  0.721893 -0.124034  1.000000  0.091864
# live         -0.101074  0.060197  0.169188 -0.085405  0.091864  1.000000
# val          -0.126548 -0.002504  0.388049  0.286068  0.276934  0.055707
# acous         0.119288 -0.097414 -0.440690 -0.067270 -0.326809 -0.131357
# spch          0.034592  0.065496 -0.089536  0.132662 -0.175409  0.107341
# pop           0.481381 -0.013730 -0.190967  0.106985 -0.100232 -0.091236
# duration_sec -0.279296 -0.015085 -0.018839 -0.160889 -0.074097  0.009931
# duration_min -0.279296 -0.015085 -0.018839 -0.160889 -0.074097  0.009931
#
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
plt.figure(figsize=(12,8)) # the size of the figure needs to be specifed before plotting
plt.scatter(x = data_new['pop'], y = data_new['dB'], alpha = 0.6)
# alpha parameter controls the opacity and transparency of the bubbles 
plt.xscale('log') # what does this do? 

# the next functions add labels and title to the plot 
plt.xlabel('popularity')
plt.ylabel('how loud the track is')
plt.title('Does the loudness affect tracks popularity?')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12,8)) # the size of the figure needs to be specifed before plotting
plt.scatter(x = data_new['nrgy'], y = data_new['pop'], alpha = 0.6)
# alpha parameter controls the opacity and transparency of the bubbles 
plt.xscale('log') # what does this do? 

# the next functions add labels and title to the plot 
plt.xlabel('how energic the song is')
plt.ylabel('popularity')
plt.title('Does the energy level affekt popularity of the track? ')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12,6))
g =sns.scatterplot(x="nrgy", y="pop", hue="bpm", size = "pop", data=data_new)
g.set(xscale="log")

plt.show()

# %%
data_new.dtypes
# Out:
# title            object
# artist           object
# top genre        object
# year              int64
# bpm               int64
# nrgy              int64
# dnce              int64
# dB                int64
# live              int64
# val               int64
# acous             int64
# spch              int64
# pop               int64
# duration_sec      int64
# duration_min    float64
# dtype: object

# %% [markdown]
# I want to create a stacked bar graph over the years development in bpm.

# %%
#import matplotlib.pyplot as plt
#import numpy as np
#import pandas as pd
#from textwrap import wrap
#
#data = data_new[['year', 'spch', 'val', 'dnce']]
#year = data_new.iloc[:, 0]
#spechness = data_new.iloc[:, 1]
#valence = data_new.iloc[:, 2]
#dance = data_new.iloc[:, 3]
#indx = np.arange(len(data))
#
#plt.figure(figsize=(10,7))
#
#graphspech = plt.bar(x=indx, height=spechness, width=0.35)
#graphval = plt.bar(x=indx, height=valence, width=0.35, bottom= spechness)
#graphdance = plt.bar(x=indx, height=dance, width=0.35, bottom= valence + spechness)
#
#plt.xlabel('year')
#plt.ylabel('features per year')
#
#plt.show()
#

# %%
years = [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,2014,2015,2016,2017,2018,2019]
fea_bpm_mean = np.array([118.666667,121.627451,112.905882,120.786667,125.136842,125.753425,117.404494,129.054945,121.892157,125.358025,124.849462,120.903614,121.129870,118.063158,119.875000,127.229508])
fea_nrgy_mean = np.array([75.666667,68.529412,68.164706,73.000000,72.284211,73.821918,75.988764,73.406593,74.401961,70.925926,67.107527,63.710843,62.818182,63.789474,62.437500,62.098361])
fea_dnce_mean = np.array([68.333333,66.470588,68.564706,63.666667,66.747368, 59.904110,64.606742,62.472527,64.696078,63.703704,65.612903,66.518072,67.766234,71.705263,72.583333,71.672131])
fea_dB_mean = np.array([5.333333,5.843137,5.800000,5.253333,5.294737, 5.013699,4.977528,5.197802,5.117647,5.530864,5.881720,6.012048,6.272727,6.063158,5.927083,6.016393])
fea_live_mean = np.array([9.333333,19.784314,17.952941,18.026667,17.389474,21.424658,21.337079,17.879121,19.215686,16.851852,16.870968,17.867470,15.662338,14.757895,16.375000,13.934426])
fea_val_mean = np.array([57.333333,51.392157,57.964706,53.000000,55.147368,53.191781,56.000000,52.758242,56.980392,51.987654,52.677419,47.638554,45.675325,49.831579,43.895833,52.032787])
fea_acous_mean = np.array([9.000000,12.627451,12.188235,12.733333,10.094737,12.945205,11.943820,13.076923,9.970588,13.530864,14.698925,18.301205,16.740260,15.705263,17.354167,19.540984])
fea_spch_mean = np.array([3.666667,11.647059,13.011765,12.480000,8.947368,9.506849,10.123596,9.934066,8.196078,8.148148,8.139785,9.361446,11.506494,11.863158,12.760417,14.721311])

fig = plt.figure(figsize=(11,5))

ind = [x for x, _ in enumerate(years)]


plt.bar(ind, fea_spch_mean, width=0.8, label='fea_spch_mean', color='yellow', bottom=fea_acous_mean+fea_val_mean+fea_live_mean+fea_dB_mean+fea_dnce_mean+fea_nrgy_mean+fea_bpm_mean)
plt.bar(ind, fea_acous_mean, width=0.8, label='fea_acous_mean', color='gold', bottom=fea_val_mean+fea_live_mean+fea_dB_mean+fea_dnce_mean+fea_nrgy_mean+fea_bpm_mean)
plt.bar(ind, fea_val_mean, width=0.8, label='fea_val_mean', color='red', bottom=fea_live_mean+fea_dB_mean+fea_dnce_mean+fea_nrgy_mean+fea_bpm_mean)
plt.bar(ind, fea_live_mean, width=0.8, label='fea_live_mean', color='pink', bottom=fea_dB_mean+fea_dnce_mean+fea_nrgy_mean+fea_bpm_mean)
plt.bar(ind, fea_dB_mean, width=0.8, label='fea_dB_mean', color='silver', bottom=fea_dnce_mean+fea_nrgy_mean+fea_bpm_mean)
plt.bar(ind, fea_dnce_mean, width=0.8, label='fea_dnce_mean', color='black', bottom=fea_nrgy_mean+fea_bpm_mean)
plt.bar(ind, fea_nrgy_mean, width=0.8, label='fea_nrgy_mean', color='brown', bottom=fea_bpm_mean)
plt.bar(ind, fea_bpm_mean, width=0.8, label='fea_bpm_mean', color='blue')
#plt.bar(ind, years, width=0.8, label='years', color='#CD853F')

plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')

plt.xticks(ind, years)
plt.ylabel("Accumulated index")
plt.xlabel("Years")
#plt.legend(loc="upper right")
plt.title("Feature development over the years")

fig.legend(bbox_to_anchor=(0.97, 0.50))


plt.show()

# %%
data_new.loc[data_new['year'] == 2019].mean()
# Out:
# year            2019.000000
# bpm              127.229508
# nrgy              62.098361
# dnce              71.672131
# dB                -6.016393
# live              13.934426
# val               52.032787
# acous             19.540984
# spch              14.721311
# pop               78.803279
# duration_sec     187.524590
# duration_min       3.125410
# dtype: float64

# %%
data_new['year'].describe()
# Out:
# count    1250.000000
# mean     2012.134400
# std         4.146962
# min      2004.000000
# 25%      2009.000000
# 50%      2012.000000
# 75%      2016.000000
# max      2019.000000
# Name: year, dtype: float64

# %%
data_new.describe()
# Out:
#               year          bpm         nrgy         dnce           dB  \
# count  1250.000000  1250.000000  1250.000000  1250.000000  1250.000000
# mean   2012.134400   122.016800    68.985600    66.479200    -5.597600
# std       4.146962    28.073115    15.768992    13.716329     1.930455
# min    2004.000000    60.000000     6.000000    21.000000   -18.000000
# 25%    2009.000000   100.000000    59.000000    58.000000    -7.000000
# 50%    2012.000000   122.000000    71.000000    67.000000    -5.000000
# 75%    2016.000000   140.000000    81.000000    76.000000    -4.000000
# max    2019.000000   211.000000    98.000000    98.000000    -1.000000
#
#               live          val        acous         spch          pop  \
# count  1250.000000  1250.000000  1250.000000  1250.000000  1250.000000
# mean     17.651200    52.093600    13.965600    10.529600    68.740000
# std      12.846508    21.625535    18.280519    10.052122    10.304122
# ...

# %%
data_new.loc[data_new['year'] == 2006].mean()
# Out:
# year            2006.000000
# bpm              112.905882
# nrgy              68.164706
# dnce              68.564706
# dB                -5.800000
# live              17.952941
# val               57.964706
# acous             12.188235
# spch              13.011765
# pop               61.141176
# duration_sec     244.494118
# duration_min       4.074902
# dtype: float64
